# %% [markdown]
# # STS Examples

# %%
from Import import *
from Convert import *
from STS_Analysis import *

# %% [markdown]
# ## Plotting 2D

# %% [markdown]
# ### IV Heatmap

# %%
plot_IVmaps()

# %% [markdown]
# # Plotting 3D

# %%
IV_map = read_in_IVmap()
IV_map = IVmap_normalize(IV_map)


plot_IVmap(IV_map, log = False)
plt.title('IV Heatmap, Simple Log')
plt.show()

plot_IVmap(IV_map)
plt.title('IV Heatmap, Simple Log')
plt.show()

plot_IVmap(IV_map,logmod = 10000)
plt.title('IV Heatmap, Log adjusted')
plt.show()

plot_IVmap(IV_map,logmod = 10000,nozeros = True)
plt.title('IV Heatmap, Log adjusted,Only Data')
plt.show()

plot_IVmap(IV_map,logmod = 10000)
plt.title('IV Heatmap, Log adjusted')
plt.show()

# %% [markdown]
# ### IV maps wireframe
