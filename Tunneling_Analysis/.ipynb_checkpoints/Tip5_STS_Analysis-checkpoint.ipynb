# %%
from Convert import convert_sSTSset
from STS_Analysis import plot_IVmaps
from Import import subfolders, choose_folder, choose_files
import pandas as pd
from IPython.display import clear_output
pd.options.mode.chained_assignment = None

# %% [markdown]
# # STS 2 - Maybe Molecule

# %% [markdown]
# ## 1V/s sweep rate

# %%
#paths = choose_files()
#print(paths)
paths = ['D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/-IV-Slope-    1 Vps    __IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/3_dsp-IV-Slope-    1 Vps_IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/1_dsp-IV-Slope-    1 Vps_IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/0_dsp-IV-Slope-    1 Vps_IVbin.txt']

plot_IVmaps(paths,logmod = 10000)

# %%
#paths = choose_files()
#print(paths)
paths = ['D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/-IV-Slope-    1 Vps    __dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/3_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/1_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/0_dsp-IV-Slope-    1 Vps_dIdVVbin.txt']
plot_IVmaps(paths,logmod = 10000)
# Out:
# ('D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/-IV-Slope-    1 Vps    __dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/3_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/1_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/0_dsp-IV-Slope-    1 Vps_dIdVVbin.txt')

# %%
paths = choose_files()
print(paths)

plot_IVmaps(paths,logmod = 10000)
# Out:
# ('D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/-IV-Slope-    1 Vps    __ZFbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/3_dsp-IV-Slope-    1 Vps_ZFbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/1_dsp-IV-Slope-    1 Vps_ZFbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/0_dsp-IV-Slope-    1 Vps_ZFbin.txt')

# %% [markdown]
# ## 0.5 V/s sweep rate

# %%
paths = choose_files()
print(paths)

plot_IVmaps(paths,logmod = 10000)
# Out:
# ('D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/-IV-Slope-  0p5 Vps    __IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/3_dsp-IV-Slope-  0p5 Vps_IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/1_dsp-IV-Slope-  0p5 Vps_IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/0_dsp-IV-Slope-  0p5 Vps_IVbin.txt')

# %%
paths = choose_files()
print(paths)

plot_IVmaps(paths,logmod = 10000)
# Out:
# ('D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/-IV-Slope-  0p5 Vps    __dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/3_dsp-IV-Slope-  0p5 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/1_dsp-IV-Slope-  0p5 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_2_maybeMolecule/0_dsp-IV-Slope-  0p5 Vps_dIdVVbin.txt')

# %% [markdown]
# # STS 3

# %%
#paths = choose_files()
#print(paths)
paths = ['D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/0_dsp-IV-Slope-    1 Vps_IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/1_dsp-IV-Slope-    1 Vps_IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/2_dsp-IV-Slope-    1 Vps_IVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/-IV-Slope-    1 Vps    __IVbin.txt']
plot_IVmaps(paths,logmod = 10000)

# %%
#paths = choose_files()
#print(paths)
paths = ['D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/2_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/1_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/0_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/-IV-Slope-    1 Vps    __dIdVVbin.txt']
plot_IVmaps(paths,logmod = 10000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 #paths = choose_files()
#       2 #print(paths)
#       3 paths = ['D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/2_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/1_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/0_dsp-IV-Slope-    1 Vps_dIdVVbin.txt', 'D:/Work/Stress Test/New_Island/Tip5_newisland_allgrounded/STS_Test_3/-IV-Slope-    1 Vps    __dIdVVbin.txt']
# ----> 4 plot_IVmaps(paths,logmod = 10000)
#
# File D:\Work\GitHub\Tunneling-Analysis\Tunneling_Analysis\STS_Analysis.py:266, in plot_IVmaps(paths, **kwargs)
#     264     paths = paths
#     265 for i in paths:
# --> 266     IV_map = read_in_IVmap(i)
#     267     im  = plot_IVmap(IV_map,**kwargs)
# ...
